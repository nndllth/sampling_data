# %% [markdown]
# <a href="https://colab.research.google.com/github/nndllth/sampling_data/blob/main/Bootcamp_Tugas_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import normalize

# %%
cars_data = pd.read_csv('/content/autos.csv',encoding='Windows-1252')

# %% [markdown]
# #No 1

# %% [markdown]
# 10 data teratas

# %%
cars_data.head(10)
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5  2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6  2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7  2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8  2016-03-22 16:51:34                                         Seat_Arosa
# 9  2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# ...

# %% [markdown]
# statistik dari tiap kolom

# %%
cars_data.describe(include='all')
# Out:
#                 dateCrawled         name  seller offerType  price abtest  \
# count                 50000        50000   50000     50000  50000  50000
# unique                48213        38754       2         2   2357      2
# top     2016-04-02 11:37:04  Ford_Fiesta  privat   Angebot     $0   test
# freq                      3           78   49999     49999   1421  25756
# mean                    NaN          NaN     NaN       NaN    NaN    NaN
# std                     NaN          NaN     NaN       NaN    NaN    NaN
# min                     NaN          NaN     NaN       NaN    NaN    NaN
# 25%                     NaN          NaN     NaN       NaN    NaN    NaN
# 50%                     NaN          NaN     NaN       NaN    NaN    NaN
# 75%                     NaN          NaN     NaN       NaN    NaN    NaN
# max                     NaN          NaN     NaN       NaN    NaN    NaN
#
#        vehicleType  yearOfRegistration  gearbox       powerPS  model  \
# ...

# %% [markdown]
# Tipe data dari tiap kolom

# %%
cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  object
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  object
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer             50000 non-null  object
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
# ...

# %% [markdown]
# Persentase nilai Null

# %%
(cars_data.isna().sum()/len(cars_data))*100
# Out:
# dateCrawled             0.000
# name                    0.000
# seller                  0.000
# offerType               0.000
# price                   0.000
# abtest                  0.000
# vehicleType            10.190
# yearOfRegistration      0.000
# gearbox                 5.360
# powerPS                 0.000
# model                   5.516
# odometer                0.000
# monthOfRegistration     0.000
# fuelType                8.964
# brand                   0.000
# notRepairedDamage      19.658
# dateCreated             0.000
# nrOfPictures            0.000
# postalCode              0.000
# lastSeen                0.000
# dtype: float64

# %% [markdown]
# #No 3

# %%
cars_data["dateCreated"] = pd.to_datetime(cars_data["dateCreated"], dayfirst=True)
cars_data["dateCrawled"] = pd.to_datetime(cars_data["dateCrawled"], dayfirst=True)
cars_data["lastSeen"] = pd.to_datetime(cars_data["lastSeen"], dayfirst=True)
cars_data[["dateCreated", "dateCrawled", "lastSeen"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   dateCreated  50000 non-null  datetime64[ns]
#  1   dateCrawled  50000 non-null  datetime64[ns]
#  2   lastSeen     50000 non-null  datetime64[ns]
# dtypes: datetime64[ns](3)
# memory usage: 1.1 MB

# %% [markdown]
# #No 4

# %%
cars_data["price"] = cars_data["price"].str.replace("$","").str.replace(",","").astype('int')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# #No 5

# %%
a = cars_data['name'].value_counts()
b = cars_data['seller'].value_counts()
c = cars_data['offerType'].value_counts()
d = cars_data['abtest'].value_counts()
e = cars_data['vehicleType'].value_counts()
f = cars_data['gearbox'].value_counts()
g = cars_data['model'].value_counts()
h = cars_data['fuelType'].value_counts()
i = cars_data['brand'].value_counts()
j = cars_data['notRepairedDamage'].value_counts()
print(a)
print("")

print(b)
print("")

print(c)
print("")

print(d)
print("")

print(e)
print("")

print(f)
print("")

print(g)
print("")

print(h)
print("")

print(i)
print("")

print(j)
# Out:
# Ford_Fiesta                                                 78
# Volkswagen_Golf_1.4                                         75
# BMW_316i                                                    75
# BMW_318i                                                    72
# Volkswagen_Polo                                             72
#                                                             ..
# peugeot_206_bj_2000rot_4tuerig_ohne_tuev_bastlerfahrzeug     1
# Volvo_Volvo_S60_2.4                                          1
# Sparsamer_Mitsubishi_Cold                                    1
# SEAT_ALTEA_2.0_TDI__AUTOMATIK                                1
# Fiat_500_C_1.2_Dualogic_Lounge                               1
# Name: name, Length: 38754, dtype: int64
#
# privat        49999
# gewerblich        1
# Name: seller, dtype: int64
#
# Angebot    49999
# Gesuch         1
# Name: offerType, dtype: int64
#
# test       25756
# control    24244
# Name: abtest, dtype: int64
#
# limousine     12859
# ...

# %% [markdown]
# #No 6

# %%
cars_data['price'].sort_values()
# Out:
# 18089           0
# 43923           0
# 15225           0
# 29499           0
# 8445            0
#            ...
# 27371    12345678
# 47598    12345678
# 39377    12345678
# 42221    27322222
# 39705    99999999
# Name: price, Length: 50000, dtype: int64

# %%
cars_data.drop(cars_data[(cars_data['price'] > 40000)].index, inplace=True) 
cars_data.drop(cars_data[(cars_data['price'] < 500)].index, inplace=True)
cars_data['price'].sort_values()
# Out:
# 2679       500
# 24823      500
# 16598      500
# 14044      500
# 35373      500
#          ...
# 28668    39999
# 6128     39999
# 41720    40000
# 31578    40000
# 13897    40000
# Name: price, Length: 44752, dtype: int64

# %% [markdown]
# #No 7

# %%
data = cars_data.copy()
object_cols = cars_data.select_dtypes(include = 'object').columns
nemueric_cols = cars_data.select_dtypes(include = 'int').columns

cars_data[object_cols] = cars_data[object_cols].fillna(cars_data[object_cols].mode())
cars_data[nemueric_cols] = cars_data[nemueric_cols].fillna(cars_data[nemueric_cols].median())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44752 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          44752 non-null  datetime64[ns]
#  1   name                 44752 non-null  object
#  2   seller               44752 non-null  object
#  3   offerType            44752 non-null  object
#  4   price                44752 non-null  int64
#  5   abtest               44752 non-null  object
#  6   vehicleType          41085 non-null  object
#  7   yearOfRegistration   44752 non-null  int64
#  8   gearbox              42950 non-null  object
#  9   powerPS              44752 non-null  int64
#  10  model                42712 non-null  object
#  11  odometer             44752 non-null  object
#  12  monthOfRegistration  44752 non-null  int64
#  13  fuelType             41570 non-null  object
#  14  brand                44752 non-null  object
# ...
